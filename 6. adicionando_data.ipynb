# %% [markdown]
# #### NAO EXECUTAR

# %%
from google.cloud import bigquery
import pandas as pd

# %%
# CREDENCIAL EXTRACT    utiliza from_service_account_json()
credencial = r'C:\fora do onedrive\Python Scripts\google big query\credenciais json\python-curso-437819-ad5456cc6222.json'

client = bigquery.Client.from_service_account_json(credencial)

# %%
mercado_original = pd.read_csv(r'C:\fora do onedrive\Python Scripts\SQL\fazendo minhas coisas\banco de dados mercado\banco de dados mercado.csv', delimiter=';')

mercado_original.head()
# Out:
#            Produtos  Categoria Preco  ID       Marca  Estoque    Validade  \
# 0             Arroz  Alimentos  22,9   1    Tio João       50  01/12/2024
# 1            Feijão  Alimentos   8,5   2       Camil       40  15/11/2024
# 2            Açúcar  Alimentos   4,3   3       União       60  10/03/2025
# 3  Farinha de trigo  Alimentos   5,6   4  Dona Benta       35  20/04/2025
# 4      Óleo de soja  Alimentos   9,8   5        Liza       45  05/01/2025
#
#           Fornecedor Preco_Por_Unidade    Origem    Peso
# 0  Distribuidora XYZ         2,29 (kg)  Nacional    5 kg
# 1    Atacado Central         4,25 (kg)  Nacional    1 kg
# 2  Distribuidora ABC         4,30 (kg)  Nacional    1 kg
# 3    Atacado Central         2,80 (kg)  Nacional    1 kg
# 4  Distribuidora XYZ      9,80 (litro)  Nacional  900 ml

# %%
datas = [
    '22/09/2024',
    '20/09/2024',
    '28/09/2024',
    '11/09/2024',
    '25/09/2024',
    '23/09/2024',
    '22/09/2024',
    '08/10/2024',
    '10/10/2024',
    '13/09/2024',
    '30/09/2024',
    '01/10/2024',
    '10/10/2024',
    '05/10/2024',
    '10/10/2024',
    '16/09/2024',
    '26/09/2024',
    '07/10/2024',
    '26/09/2024',
    '06/10/2024',
    '25/09/2024',
    '01/10/2024',
    '11/09/2024',
    '10/10/2024',
    '30/09/2024',
    '11/09/2024',
    '10/10/2024',
    '23/09/2024',
    '28/09/2024',
    '28/09/2024'
]

# %%
mercado_original['Data'] = pd.Series((datas * (len(mercado_original) // len(datas) + 1))[:len(mercado_original)])

# %%
print(len(datas))
len((mercado_original))

# Exibir as primeiras linhas do DataFrame
print(mercado_original.head())
# Exibir o número de linhas e colunas
print(mercado_original.shape)
# Out:
# 30
#            Produtos  Categoria Preco  ID       Marca  Estoque    Validade  \
# 0             Arroz  Alimentos  22,9   1    Tio João       50  01/12/2024
# 1            Feijão  Alimentos   8,5   2       Camil       40  15/11/2024
# 2            Açúcar  Alimentos   4,3   3       União       60  10/03/2025
# 3  Farinha de trigo  Alimentos   5,6   4  Dona Benta       35  20/04/2025
# 4      Óleo de soja  Alimentos   9,8   5        Liza       45  05/01/2025
#
#           Fornecedor Preco_Por_Unidade    Origem    Peso        Data
# 0  Distribuidora XYZ         2,29 (kg)  Nacional    5 kg  22/09/2024
# 1    Atacado Central         4,25 (kg)  Nacional    1 kg  20/09/2024
# 2  Distribuidora ABC         4,30 (kg)  Nacional    1 kg  28/09/2024
# 3    Atacado Central         2,80 (kg)  Nacional    1 kg  11/09/2024
# 4  Distribuidora XYZ      9,80 (litro)  Nacional  900 ml  25/09/2024
# (30, 12)

# %%
mercado_original.head()
# Out:
#            Produtos  Categoria Preco  ID       Marca  Estoque    Validade  \
# 0             Arroz  Alimentos  22,9   1    Tio João       50  01/12/2024
# 1            Feijão  Alimentos   8,5   2       Camil       40  15/11/2024
# 2            Açúcar  Alimentos   4,3   3       União       60  10/03/2025
# 3  Farinha de trigo  Alimentos   5,6   4  Dona Benta       35  20/04/2025
# 4      Óleo de soja  Alimentos   9,8   5        Liza       45  05/01/2025
#
#           Fornecedor Preco_Por_Unidade    Origem    Peso        Data
# 0  Distribuidora XYZ         2,29 (kg)  Nacional    5 kg  22/09/2024
# 1    Atacado Central         4,25 (kg)  Nacional    1 kg  20/09/2024
# 2  Distribuidora ABC         4,30 (kg)  Nacional    1 kg  28/09/2024
# 3    Atacado Central         2,80 (kg)  Nacional    1 kg  11/09/2024
# 4  Distribuidora XYZ      9,80 (litro)  Nacional  900 ml  25/09/2024

# %%
query_mercado = '''

SELECT * FROM `python-curso-437819.conjunto2.Mercado`

'''

resultado_mercado = client.query(query_mercado)

mercado = resultado_mercado.to_dataframe()
# Out:
# c:\Users\henry\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
mercado_original['Data'] = pd.to_datetime(mercado_original['Data'], format='%d/%m/%Y', errors='coerce')

# %%
mercado_original
# Out:
#                   Produtos  Categoria Preco  ID           Marca  Estoque  \
# 0                    Arroz  Alimentos  22,9   1        Tio João       50
# 1                   Feijão  Alimentos   8,5   2           Camil       40
# 2                   Açúcar  Alimentos   4,3   3           União       60
# 3         Farinha de trigo  Alimentos   5,6   4      Dona Benta       35
# 4             Óleo de soja  Alimentos   9,8   5            Liza       45
# 5                      Sal  Alimentos   2,5   6           Cisne      100
# 6                 Macarrão  Alimentos   4,2   7          Renata       70
# 7                     Café  Alimentos    15   8           Pilão       20
# 8                    Leite  Alimentos   4,9   9        Parmalat       25
# 9                 Manteiga  Alimentos  12,4  10         Aviação       15
# 10                  Queijo  Alimentos    18  11        Polenghi       10
# 11                 Iogurte  Alimentos   7,3  12           Vigor       30
# ...

# %%
mercado.head(5)
# Out:
#              Produtos Categoria Preco  ID      Marca  Estoque    Validade  \
# 0        Água mineral   Bebidas   1,8  26     Rexona      120  01/07/2025
# 1    Suco de caixinha   Bebidas   5,4  27   Bonafont       30  20/12/2024
# 2        Refrigerante   Bebidas   7,5  28  Del Valle       25  30/11/2024
# 3         Sabão em pó   Higiene  16,5  19        Omo       20  01/12/2024
# 4  Detergente líquido   Higiene   3,5  20        Ypê      100  01/03/2025
#
#                    Fornecedor Preco_Por_Unidade    Origem      Peso
# 0        Atacado Bebidas LTDA      0,90 (litro)  Nacional    500 ml
# 1     Fornecedor Bebidas LTDA      5,40 (litro)  Nacional   1 litro
# 2        Atacado Bebidas LTDA   7,50 (2 litros)  Nacional  2 litros
# 3  Distribuidora Higiene LTDA        16,50 (kg)  Nacional      1 kg
# 4             Atacado Higiene      3,50 (litro)  Nacional    500 ml

# %%
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account
from pandas_gbq import to_gbq

# %%
# CREDENCIAL LOAD    utiliza from_service_account_file()
credencial = service_account.Credentials.from_service_account_file(
    r'C:\fora do onedrive\Python Scripts\google big query\credenciais json\python-curso-437819-ad5456cc6222.json',
    scopes=['https://www.googleapis.com/auth/bigquery'])

# %%
mercado_original.to_gbq(destination_table='python-curso-437819.conjunto2.Mercado',
          project_id='python-curso-437819',
          if_exists='replace',
          credentials=credencial)
# Out:
# C:\Users\henry\AppData\Local\Temp\ipykernel_7832\1809270162.py:1: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   mercado_original.to_gbq(destination_table='python-curso-437819.conjunto2.Mercado',

# %%
# mercado_original.to_csv('mercado_com_data.csv')
