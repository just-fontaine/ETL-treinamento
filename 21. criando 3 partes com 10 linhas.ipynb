# %%
import pandas as pd

# %%
mercado = pd.read_excel(r'C:\fora do onedrive\Python Scripts\SQL\fazendo minhas coisas\banco de dados mercado\banco de dados mercado.xlsx')
mercado.head()
# Out:
#            Produtos  Categoria  Preco  ID       Marca  Estoque   Validade  \
# 0             Arroz  Alimentos   22.9   1    Tio João       50 2024-12-01
# 1            Feijão  Alimentos    8.5   2       Camil       40 2024-11-15
# 2            Açúcar  Alimentos    4.3   3       União       60 2025-03-10
# 3  Farinha de trigo  Alimentos    5.6   4  Dona Benta       35 2025-04-20
# 4      Óleo de soja  Alimentos    9.8   5        Liza       45 2025-01-05
#
#           Fornecedor Preco_Por_Unidade    Origem    Peso
# 0  Distribuidora XYZ         2,29 (kg)  Nacional    5 kg
# 1    Atacado Central         4,25 (kg)  Nacional    1 kg
# 2  Distribuidora ABC         4,30 (kg)  Nacional    1 kg
# 3    Atacado Central         2,80 (kg)  Nacional    1 kg
# 4  Distribuidora XYZ      9,80 (litro)  Nacional  900 ml

# %%
df1 = mercado.iloc[:10].reset_index(drop=True)

df1
# Out:
#            Produtos  Categoria  Preco  ID       Marca  Estoque   Validade  \
# 0             Arroz  Alimentos   22.9   1    Tio João       50 2024-12-01
# 1            Feijão  Alimentos    8.5   2       Camil       40 2024-11-15
# 2            Açúcar  Alimentos    4.3   3       União       60 2025-03-10
# 3  Farinha de trigo  Alimentos    5.6   4  Dona Benta       35 2025-04-20
# 4      Óleo de soja  Alimentos    9.8   5        Liza       45 2025-01-05
# 5               Sal  Alimentos    2.5   6       Cisne      100 2025-08-15
# 6          Macarrão  Alimentos    4.2   7      Renata       70 2024-11-30
# 7              Café  Alimentos   15.0   8       Pilão       20 2025-07-01
# 8             Leite  Alimentos    4.9   9    Parmalat       25 2025-05-10
# 9          Manteiga  Alimentos   12.4  10     Aviação       15 2025-02-25
#
#                  Fornecedor Preco_Por_Unidade    Origem     Peso
# 0         Distribuidora XYZ         2,29 (kg)  Nacional     5 kg
# ...

# %%
df2 = mercado.iloc[10:20].reset_index(drop=True)

df2
# Out:
#                  Produtos  Categoria  Preco  ID           Marca  Estoque  \
# 0                  Queijo  Alimentos   18.0  11        Polenghi       10
# 1                 Iogurte  Alimentos    7.3  12           Vigor       30
# 2            Pão de forma  Alimentos    6.5  13         Pullman       50
# 3  Biscoito de água e sal  Alimentos    3.2  14         Marilan       80
# 4      Achocolatado em pó  Alimentos    8.9  15          Nescau       60
# 5         Molho de tomate  Alimentos    3.9  16        Elefante       90
# 6        Atum em conserva  Alimentos   12.9  17  Gomes da Costa       40
# 7        Sardinha em lata  Alimentos    6.8  18        Coqueiro       35
# 8             Sabão em pó    Higiene   16.5  19             Omo       20
# 9      Detergente líquido    Higiene    3.5  20             Ypê      100
#
#     Validade                  Fornecedor Preco_Por_Unidade     Origem    Peso
# 0 2025-06-01              Queijos Brasil        36,00 (kg)   Nacional   500 g
# ...

# %%
df3 = mercado.iloc[20:].reset_index(drop=True)

df3
# Out:
#            Produtos  Categoria  Preco  ID      Marca  Estoque   Validade  \
# 0   Papel higiênico    Higiene   12.0  21       Neve      200 2025-04-15
# 1          Sabonete    Higiene    2.8  22        Lux      150 2025-06-20
# 2           Shampoo    Higiene    9.4  23  Palmolive       60 2025-05-05
# 3     Condicionador    Higiene   10.5  24       Seda       40 2025-09-30
# 4       Desodorante    Higiene    7.2  25    Pantene       75 2025-11-01
# 5      Água mineral    Bebidas    1.8  26     Rexona      120 2025-07-01
# 6  Suco de caixinha    Bebidas    5.4  27   Bonafont       30 2024-12-20
# 7      Refrigerante    Bebidas    7.5  28  Del Valle       25 2024-11-30
# 8    Cereal matinal  Alimentos    9.9  29  Coca-Cola       35 2025-04-01
# 9               Ovo  Alimentos   14.0  30  Kellogg's      150 2025-09-15
#
#                    Fornecedor Preco_Por_Unidade     Origem         Peso
# 0             Atacado Higiene       1,50 (rolo)   Nacional      4 rolos
# ...

# %%
df1.to_excel('mercado2020.xlsx', index=False)

# %%
df2.to_excel('mercado2021.xlsx', index=False)

# %%
df3.to_excel('mercado2022.xlsx', index=False)
