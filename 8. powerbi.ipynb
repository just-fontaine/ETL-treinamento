# %%
import pandas as pd
import os
import subprocess
import sys

def install_matplotlib():
    subprocess.check_call([sys.executable, "-m", "pip", "install", "matplotlib"])

# Tente importar o matplotlib, e se não estiver instalado, instale-o.
try:
    import matplotlib
except ModuleNotFoundError:
    install_matplotlib()
    import matplotlib

# DIRÉTORIO

diretorio = (r"C:\fora do onedrive\Python Scripts\Arquivos\duas metades")

# LISTA PARA ARMAZENAR OS DADOS DOS ARQUIVOS

dados = []

for arquivo in os.listdir(diretorio):
    if arquivo.endswith('csv'):
        caminho_arquivo = os.path.join(diretorio, arquivo)
        df = pd.read_csv(caminho_arquivo)
        dados.append(df)

# CONSOLIDAR EM UM UNICO DATA FRAME

consolidado = pd.concat(dados)
consolidado
# Out:
#         Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday  \
# 0                0      1     1  2010-02-05      24924.50      False
# 1                1      1     2  2010-02-05      50605.27      False
# 2                2      1     3  2010-02-05      13740.12      False
# 3                3      1     4  2010-02-05      39954.04      False
# 4                4      1     5  2010-02-05      32229.38      False
# ...            ...    ...   ...         ...           ...        ...
# 210101      210771     22    54  2011-02-11        109.92       True
# 210102      210772     22    55  2011-02-11       9209.60       True
# 210103      210773     22    56  2011-02-11        881.14       True
# 210104      210774     22    58  2011-02-11       1345.00       True
# 210105      210775     22    59  2011-02-11        555.88       True
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  ...  Unemployment  \
# ...
