# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\fora do onedrive\Python Scripts\SQL\fazendo minhas coisas\banco de dados mercado\mercado_com_data.csv')

# %%
df.head()
# Out:
#            Produtos  Categoria Preco  ID       Marca  Estoque    Validade  \
# 0             Arroz  Alimentos  22,9   1    Tio João       50  01/12/2024
# 1            Feijão  Alimentos   8,5   2       Camil       40  15/11/2024
# 2            Açúcar  Alimentos   4,3   3       União       60  10/03/2025
# 3  Farinha de trigo  Alimentos   5,6   4  Dona Benta       35  20/04/2025
# 4      Óleo de soja  Alimentos   9,8   5        Liza       45  05/01/2025
#
#           Fornecedor Preco_Por_Unidade    Origem    Peso        Data
# 0  Distribuidora XYZ         2,29 (kg)  Nacional    5 kg  22/09/2024
# 1    Atacado Central         4,25 (kg)  Nacional    1 kg  20/09/2024
# 2  Distribuidora ABC         4,30 (kg)  Nacional    1 kg  28/09/2024
# 3    Atacado Central         2,80 (kg)  Nacional    1 kg  11/09/2024
# 4  Distribuidora XYZ      9,80 (litro)  Nacional  900 ml  25/09/2024

# %%
df.query(" Produtos == 'Arroz' ")
# Out:
#   Produtos  Categoria Preco  ID     Marca  Estoque    Validade  \
# 0    Arroz  Alimentos  22,9   1  Tio João       50  01/12/2024
#
#           Fornecedor Preco_Por_Unidade    Origem  Peso        Data
# 0  Distribuidora XYZ         2,29 (kg)  Nacional  5 kg  22/09/2024

# %%
arroz_feijao_acucar = df.query(" Produtos in ('Arroz', 'Feijão', 'Açúcar') ")

arroz_feijao_acucar
# Out:
#   Produtos  Categoria Preco  ID     Marca  Estoque    Validade  \
# 0    Arroz  Alimentos  22,9   1  Tio João       50  01/12/2024
# 1   Feijão  Alimentos   8,5   2     Camil       40  15/11/2024
# 2   Açúcar  Alimentos   4,3   3     União       60  10/03/2025
#
#           Fornecedor Preco_Por_Unidade    Origem  Peso        Data
# 0  Distribuidora XYZ         2,29 (kg)  Nacional  5 kg  22/09/2024
# 1    Atacado Central         4,25 (kg)  Nacional  1 kg  20/09/2024
# 2  Distribuidora ABC         4,30 (kg)  Nacional  1 kg  28/09/2024

# %%
df.query(" Preco > 10 ").head()
# Out:
#             Produtos  Categoria  Preco  ID           Marca  Estoque  \
# 0              Arroz  Alimentos   22.9   1        Tio João       50
# 7               Café  Alimentos   15.0   8           Pilão       20
# 9           Manteiga  Alimentos   12.4  10         Aviação       15
# 10            Queijo  Alimentos   18.0  11        Polenghi       10
# 16  Atum em conserva  Alimentos   12.9  17  Gomes da Costa       40
#
#       Validade                Fornecedor Preco_Por_Unidade     Origem   Peso  \
# 0   01/12/2024         Distribuidora XYZ         2,29 (kg)   Nacional   5 kg
# 7   01/07/2025      Fornecedor Café LTDA        30,00 (kg)   Nacional  500 g
# 9   25/02/2025  Distribuidora Laticínios      12,40 (250g)   Nacional  250 g
# 10  01/06/2025            Queijos Brasil        36,00 (kg)   Nacional  500 g
# 16  15/09/2025          Atacado Pescados        43,00 (kg)  Importado  300 g
#
#           Data
# 0   22/09/2024
# 7   08/10/2024
# 9   13/09/2024
# 10  30/09/2024
# ...

# %%
df
# Out:
#                   Produtos  Categoria  Preco  ID           Marca  Estoque  \
# 0                    Arroz  Alimentos   22.9   1        Tio João       50
# 1                   Feijão  Alimentos    8.5   2           Camil       40
# 2                   Açúcar  Alimentos    4.3   3           União       60
# 3         Farinha de trigo  Alimentos    5.6   4      Dona Benta       35
# 4             Óleo de soja  Alimentos    9.8   5            Liza       45
# 5                      Sal  Alimentos    2.5   6           Cisne      100
# 6                 Macarrão  Alimentos    4.2   7          Renata       70
# 7                     Café  Alimentos   15.0   8           Pilão       20
# 8                    Leite  Alimentos    4.9   9        Parmalat       25
# 9                 Manteiga  Alimentos   12.4  10         Aviação       15
# 10                  Queijo  Alimentos   18.0  11        Polenghi       10
# 11                 Iogurte  Alimentos    7.3  12           Vigor       30
# ...

# %%
filtro_origem = ['Distribuidora XYZ', 'Distribuidora ABC', 'Distribuidora Higiene LTDA', 'Atacado Bebidas LTDA']

df.query('Fornecedor in @filtro_origem') # @ FAZ REFERENCIA A VARIAVEL
# Out:
#         Produtos  Categoria  Preco  ID      Marca  Estoque    Validade  \
# 0          Arroz  Alimentos   22.9   1   Tio João       50  01/12/2024
# 2         Açúcar  Alimentos    4.3   3      União       60  10/03/2025
# 4   Óleo de soja  Alimentos    9.8   5       Liza       45  05/01/2025
# 6       Macarrão  Alimentos    4.2   7     Renata       70  30/11/2024
# 18   Sabão em pó    Higiene   16.5  19        Omo       20  01/12/2024
# 21      Sabonete    Higiene    2.8  22        Lux      150  20/06/2025
# 25  Água mineral    Bebidas    1.8  26     Rexona      120  01/07/2025
# 27  Refrigerante    Bebidas    7.5  28  Del Valle       25  30/11/2024
#
#                     Fornecedor Preco_Por_Unidade    Origem      Peso  \
# 0            Distribuidora XYZ         2,29 (kg)  Nacional      5 kg
# 2            Distribuidora ABC         4,30 (kg)  Nacional      1 kg
# 4            Distribuidora XYZ      9,80 (litro)  Nacional    900 ml
# ...
