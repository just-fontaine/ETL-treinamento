# %%
import pandas as pd
import pyodbc

# %%
server = r'DESKTOP-5KQL2U6\MSSQLSERVER01'
database = 'Python'
conexaoDB = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                           f'SERVER={server};'
                           f'DATABASE={database};'
                           'Trusted_Connection=yes;')

cursor = conexaoDB.cursor()

# %%
cursor.close()

# %%
query = """

select * from [dbo].[Parte3]
where Estoque > 40

"""

# %%
estoque = pd.read_sql(query, conexaoDB)

estoque.head(10)

# %% [markdown]
# #### CRIAR CONEXÃO COM OUTRO BANCO DE DADOS/SERVIDOR

# %%
server2 = r'DESKTOP-5KQL2U6\MSSQLSERVER01'
database2 = 'Python2'
conexaoDB2 = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                           f'SERVER={server2};'
                           f'DATABASE={database2};'
                           'Trusted_Connection=yes;')

cursor2 = conexaoDB2.cursor()

# %%
query2 = '''

select * from [dbo].[Mercado]

'''

# %%
produtos = pd.read_sql(query2, conexaoDB2)

# %%
estoque.head(5)
# Out:
#    ID  Estoque    Validade
# 0   1       50  2024-12-01
# 1   3       60  2025-03-10
# 2   5       45  2025-01-05
# 3   6      100  2025-08-15
# 4   7       70  2024-11-30

# %%
produtos.head(5)
# Out:
#            Produtos  Categoria  Preco  ID       Marca  Estoque  \
# 0             Arroz  Alimentos   22.9   1    Tio João       50
# 1            Feijão  Alimentos    8.5   2       Camil       40
# 2            Açúcar  Alimentos    4.3   3       União       60
# 3  Farinha de trigo  Alimentos    5.6   4  Dona Benta       35
# 4      Óleo de soja  Alimentos    9.8   5        Liza       45
#
#           Fornecedor Preco_Por_Unidade    Origem    Peso    Validade
# 0  Distribuidora XYZ         2,29 (kg)  Nacional    5 kg  2024-12-01
# 1    Atacado Central         4,25 (kg)  Nacional    1 kg  2024-11-15
# 2  Distribuidora ABC         4,30 (kg)  Nacional    1 kg  2025-03-10
# 3    Atacado Central         2,80 (kg)  Nacional    1 kg  2025-04-20
# 4  Distribuidora XYZ      9,80 (litro)  Nacional  900 ml  2025-01-05

# %%
join = pd.merge(estoque, produtos, left_on='ID', right_on='ID', how='left')

# %%
join
# Out:
#     ID  Estoque_x  Validade_x                Produtos  Categoria  Preco  \
# 0    1         50  2024-12-01                   Arroz  Alimentos   22.9
# 1    3         60  2025-03-10                  Açúcar  Alimentos    4.3
# 2    5         45  2025-01-05            Óleo de soja  Alimentos    9.8
# 3    6        100  2025-08-15                     Sal  Alimentos    2.5
# 4    7         70  2024-11-30                Macarrão  Alimentos    4.2
# 5   13         50  2024-12-15            Pão de forma  Alimentos    6.5
# 6   14         80  2025-03-01  Biscoito de água e sal  Alimentos    3.2
# 7   15         60  2025-10-20      Achocolatado em pó  Alimentos    8.9
# 8   16         90  2025-07-30         Molho de tomate  Alimentos    3.9
# 9   20        100  2025-03-01      Detergente líquido    Higiene    3.5
# 10  21        200  2025-04-15         Papel higiênico    Higiene   12.0
# 11  22        150  2025-06-20                Sabonete    Higiene    2.8
# ...

# %%
cursor.close()
