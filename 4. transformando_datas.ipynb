# %%
import pandas as pd
import os

# %%
caminho_arquivo = r"C:\fora do onedrive\Python Scripts\Arquivos\duas metades\consolidado\consolidado.csv"
df = pd.read_csv(caminho_arquivo)

# %%
for coluna in df.columns:
    print(f'Coluna: {coluna} Tipo de dado: {df[coluna].dtypes}')
# Out:
# Coluna: Unnamed: 0 Tipo de dado: int64
# Coluna: Store Tipo de dado: int64
# Coluna: Dept Tipo de dado: int64
# Coluna: Date Tipo de dado: object
# Coluna: Weekly_Sales Tipo de dado: float64
# Coluna: IsHoliday Tipo de dado: bool
# Coluna: Temperature Tipo de dado: float64
# Coluna: Fuel_Price Tipo de dado: float64
# Coluna: MarkDown1 Tipo de dado: float64
# Coluna: MarkDown2 Tipo de dado: float64
# Coluna: MarkDown3 Tipo de dado: float64
# Coluna: MarkDown4 Tipo de dado: float64
# Coluna: MarkDown5 Tipo de dado: float64
# Coluna: CPI Tipo de dado: float64
# Coluna: Unemployment Tipo de dado: float64
# Coluna: Type Tipo de dado: object
# Coluna: Size Tipo de dado: int64
# Coluna: Super_Bowl Tipo de dado: bool
# Coluna: Labor_Day Tipo de dado: bool
# Coluna: Thanksgiving Tipo de dado: bool
# Coluna: Christmas Tipo de dado: bool
# Coluna: week Tipo de dado: int64
# Coluna: month Tipo de dado: int64
# Coluna: year Tipo de dado: int64

# %%
df['Temperature'] = df['Temperature'].astype(int)

# %% [markdown]
# ### CONVERSÃO DE DATAS

# %%
# Tipo de dado da coluna 'Date': object

print(df['Date'].dtypes)
# Out:
# object

# %%
# Formato americano (Ano-Mês-Dia)
df
# Out:
#         Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday  \
# 0                0      1     1  2010-02-05      24924.50      False
# 1                1      1     2  2010-02-05      50605.27      False
# 2                2      1     3  2010-02-05      13740.12      False
# 3                3      1     4  2010-02-05      39954.04      False
# 4                4      1     5  2010-02-05      32229.38      False
# ...            ...    ...   ...         ...           ...        ...
# 420207      210771     22    54  2011-02-11        109.92       True
# 420208      210772     22    55  2011-02-11       9209.60       True
# 420209      210773     22    56  2011-02-11        881.14       True
# 420210      210774     22    58  2011-02-11       1345.00       True
# 420211      210775     22    59  2011-02-11        555.88       True
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  ...  Unemployment  \
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
print(df['Date'].dtypes)
# Out:
# datetime64[ns]

# %%
ano = 2010
ano2 = 2011
ano3 = 2012

# %%
df_filtrado = df[df['Date'].dt.year == ano]
df_filtrado.head()
# Out:
#    Unnamed: 0  Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           0      1     1 2010-02-05      24924.50      False           42
# 1           1      1     2 2010-02-05      50605.27      False           42
# 2           2      1     3 2010-02-05      13740.12      False           42
# 3           3      1     4 2010-02-05      39954.04      False           42
# 4           4      1     5 2010-02-05      32229.38      False           42
#
#    Fuel_Price  MarkDown1  MarkDown2  ...  Unemployment  Type    Size  \
# 0       2.572        0.0        0.0  ...         8.106     A  151315
# 1       2.572        0.0        0.0  ...         8.106     A  151315
# 2       2.572        0.0        0.0  ...         8.106     A  151315
# 3       2.572        0.0        0.0  ...         8.106     A  151315
# 4       2.572        0.0        0.0  ...         8.106     A  151315
#
#    Super_Bowl  Labor_Day Thanksgiving  Christmas  week  month  year
# ...

# %%
df_2010_fevereiro = df[(df['Date'].dt.year == 2010) & (df['Date'].dt.month == 2)]
df_2010_fevereiro
# Out:
#         Unnamed: 0  Store  Dept       Date  Weekly_Sales  IsHoliday  \
# 0                0      1     1 2010-02-05      24924.50      False
# 1                1      1     2 2010-02-05      50605.27      False
# 2                2      1     3 2010-02-05      13740.12      False
# 3                3      1     4 2010-02-05      39954.04      False
# 4                4      1     5 2010-02-05      32229.38      False
# ...            ...    ...   ...        ...           ...        ...
# 416855      207400     22    91 2010-02-26      23248.91      False
# 416856      207401     22    92 2010-02-26      48093.04      False
# 416857      207402     22    93 2010-02-26       1594.69      False
# 416858      207403     22    95 2010-02-26      51955.45      False
# 416859      207404     22    97 2010-02-26       4448.53      False
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  ...  Unemployment  \
# 0                42       2.572        0.0        0.0  ...         8.106
# ...

# %% [markdown]
# #### CONVERSÃO PARA O FORMATO BRASILEIRO DE DATAS (Dia-Mês-Ano)

# %%
# CONVERTER A COLUNA PARA O PADRAO DATETIME

df['Date'] = pd.to_datetime(df['Date'])
print(df['Date'].dtypes)
# Out:
# datetime64[ns]

# %%
# CONVERTER PARA PADRÃO BRASILEIRO

df['Date'] = df['Date'].dt.strftime('%d/%m/%Y')
df
# Out:
#         Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday  \
# 0                0      1     1  05/02/2010      24924.50      False
# 1                1      1     2  05/02/2010      50605.27      False
# 2                2      1     3  05/02/2010      13740.12      False
# 3                3      1     4  05/02/2010      39954.04      False
# 4                4      1     5  05/02/2010      32229.38      False
# ...            ...    ...   ...         ...           ...        ...
# 420207      210771     22    54  11/02/2011        109.92       True
# 420208      210772     22    55  11/02/2011       9209.60       True
# 420209      210773     22    56  11/02/2011        881.14       True
# 420210      210774     22    58  11/02/2011       1345.00       True
# 420211      210775     22    59  11/02/2011        555.88       True
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  ...  Unemployment  \
# ...

# %%
# CONVERTER PARA PADRÃO BR NO PRIMEIRO COMANDO

import pandas as pd
import os

df = pd.read_csv(r"C:\fora do onedrive\Python Scripts\Arquivos\duas metades\consolidado\consolidado.csv")

# %%
df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 1           1     2  2010-02-05      50605.27      False        42.31
# 2           1     3  2010-02-05      13740.12      False        42.31
# 3           1     4  2010-02-05      39954.04      False        42.31
# 4           1     5  2010-02-05      32229.38      False        42.31
# ...       ...   ...         ...           ...        ...          ...
# 420207     22    54  2011-02-11        109.92       True        28.89
# 420208     22    55  2011-02-11       9209.60       True        28.89
# 420209     22    56  2011-02-11        881.14       True        28.89
# 420210     22    58  2011-02-11       1345.00       True        28.89
# 420211     22    59  2011-02-11        555.88       True        28.89
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  ...  Unemployment  Type  \
# ...

# %%
# TRANSFORMAR EM DATA

df['Date'] = pd.to_datetime(df['Date'])

# %%
# CONVERTER PARA O PADRAO BRASILEIRO
df['Date'] = df['Date'].dt.strftime('%d/%m/%Y')

# %%
df.to_csv("adicionar_colunas.csv", index=False)
