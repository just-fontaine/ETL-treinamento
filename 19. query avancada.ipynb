# %%
import pandas as pd
import pyodbc

# %%
server = r'DESKTOP-5KQL2U6\MSSQLSERVER01'
database = 'Python'
conexaoDB = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                           f'SERVER={server};'
                           f'DATABASE={database};'
                           'Trusted_Connection=yes;')

cursor = conexaoDB.cursor()

# %%
query = """

select
t1.ID,
t1.Produtos,
t1.Categoria,
t2.Marca,
t2.Preco,
t4.Preco_Por_Unidade,
t2.Peso,
t3.Validade,
t3.Estoque,
t4.Fornecedor,
t4.Origem
from [dbo].[Parte1]			as t1
Left Join [dbo].[Parte2]	as t2  on t1.ID = t2.ID
Left Join [dbo].[Parte3]    as t3  on t2.ID = t3.ID
Left Join [dbo].[Parte4]    as t4  on t3.ID = t4.ID


"""

# %%
join = pd.read_sql(query, conexaoDB)

join.head(10)
# Out:
# C:\Users\henry\AppData\Local\Temp\ipykernel_11244\185543837.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   join = pd.read_sql(query, conexaoDB)
#    ID          Produtos  Categoria       Marca  Preco Preco_Por_Unidade  \
# 0   1             Arroz  Alimentos    Tio João   22.9         2,29 (kg)
# 1   2            Feijão  Alimentos       Camil    8.5         4,25 (kg)
# 2   3            Açúcar  Alimentos       União    4.3         4,30 (kg)
# 3   4  Farinha de trigo  Alimentos  Dona Benta    5.6         2,80 (kg)
# 4   5      Óleo de soja  Alimentos        Liza    9.8      9,80 (litro)
# 5   6               Sal  Alimentos       Cisne    2.5         2,50 (kg)
# 6   7          Macarrão  Alimentos      Renata    4.2         2,10 (kg)
# 7   8              Café  Alimentos       Pilão   15.0        30,00 (kg)
# ...
