# %%
# pip install pandas
# pip install --upgrade pandas

# %%
import pandas as pd

# %%
# df == data_frame
df = pd.read_csv(r"C:\fora do onedrive\Python Scripts\Arquivos\primeirosarquivos\tested.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df_female = df.loc[df['Sex'] == 'female']

df_female.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 4           896         1       3
# 6           898         1       3
# 8           900         1       3
# 12          904         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 6                            Connolly, Miss. Kate  female  30.0      0      0
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 12  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1      0
#
#      Ticket     Fare Cabin Embarked
# 1    363272   7.0000   NaN        S
# 4   3101298  12.2875   NaN        S
# 6    330972   7.6292   NaN        Q
# 8      2657   7.2292   NaN        C
# 12    21228  82.2667   B45        S

# %%
nomes = ['Kelly, Mr. James', 'Wilkes, Mrs. James (Ellen Needs)', 'Myles, Mr. Thomas Francis']

df_alguns_nomes = df.loc[df['Name'].isin(nomes)]

df_alguns_nomes.head()
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
df_alguns_nomes2 = df.loc[df['Name'].isin(['del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
                                           'Svensson, Mr. Johan Cervin',
                                             'Howard, Mr. Benjamin',
                                               'Abrahim, Mrs. Joseph (Sophie Halaut Easu)'])]
df_alguns_nomes2
# Out:
#     PassengerId  Survived  Pclass  \
# 5           897         0       3
# 8           900         1       3
# 13          905         0       2
# 15          907         1       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 13                           Howard, Mr. Benjamin    male  63.0      1      0
# 15  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1      0
#
#            Ticket     Fare Cabin Embarked
# 5            7538   9.2250   NaN        S
# 8            2657   7.2292   NaN        C
# 13          24065  26.0000   NaN        S
# 15  SC/PARIS 2167  27.7208   NaN        C

# %%
# Localizar idade > do que escolher

df_idade_maior_30 = df.loc[df['Age'] > 30]

df_idade_maior_30.head()
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 0           892         0       3                  Kelly, Mr. James    male
# 1           893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2           894         0       2         Myles, Mr. Thomas Francis    male
# 11          903         0       1        Jones, Mr. Charles Cresson    male
# 13          905         0       2              Howard, Mr. Benjamin    male
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 0   34.5      0      0  330911   7.8292   NaN        Q
# 1   47.0      1      0  363272   7.0000   NaN        S
# 2   62.0      0      0  240276   9.6875   NaN        Q
# 11  46.0      0      0     694  26.0000   NaN        S
# 13  63.0      1      0   24065  26.0000   NaN        S

# %%
# Idade entre 30 e 50
df_30_50 = df.loc[(df['Age'] > 30) & (df['Age'] < 50)]

df_30_50.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 11          903         0       1
# 14          906         1       1
# 16          908         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 16                                  Keane, Mr. Daniel    male  35.0      0
#
#     Parch       Ticket     Fare Cabin Embarked
# 0       0       330911   7.8292   NaN        Q
# 1       0       363272   7.0000   NaN        S
# 11      0          694  26.0000   NaN        S
# 14      0  W.E.P. 5734  61.1750   E31        S
# 16      0       233734  12.3500   NaN        Q
